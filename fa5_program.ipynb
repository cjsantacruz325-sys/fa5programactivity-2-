# %% [markdown]
# <a href="https://colab.research.google.com/github/cjsantacruz325-sys/fa5programactivity-2-/blob/main/fa5_program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def item_price(price, amount):
 total = price * amount
 return total

price = int(input("Please input an item quantity. "))
amount = int(input("Please input the item price (In Pesos). "))

print("Your total in Pesos is: ", total)
# Out:
# Please input an item quantity. 7
# Please input the item price (In Pesos). 5
# Your total in Pesos is:  35
